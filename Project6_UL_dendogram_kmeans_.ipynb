# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("/content/diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import scipy.cluster.hierarchy as sch
plt.title("Dendogram for diabetes dataset")
dendogram = sch.dendrogram(sch.linkage(data,method='ward'))

# %%
data_news = pd.read_csv("/content/3.01. Country clusters (1).csv")

# %%
data_news.head()
# Out:
#    Country  Latitude  Longitude Language
# 0      USA     44.97    -103.77  English
# 1   Canada     62.40     -96.80  English
# 2   France     46.75       2.40   French
# 3       UK     54.01      -2.53  English
# 4  Germany     51.15      10.40   German

# %%
df=data_news.loc[:,'Latitude':'Longitude']

# %%
df.head()
# Out:
#    Latitude  Longitude
# 0     44.97    -103.77
# 1     62.40     -96.80
# 2     46.75       2.40
# 3     54.01      -2.53
# 4     51.15      10.40

# %%
plt.title("Dendogram for country dataset")
dendogram = sch.dendrogram(sch.linkage(df,method='ward'))

# %%
from sklearn.cluster import KMeans
Kmeans=KMeans(3) #there 3 represent number of clusters

# %%
Kmeans.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
cluster=Kmeans.fit_predict(df)

# %%
print(cluster)
# Out:
# [2 2 0 0 0 1]
